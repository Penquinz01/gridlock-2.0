# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("preprosssed_gridlock.csv")

# %%
df.head()
# Out:
#   event_type   latitude  longitude  \
# 0  unplanned  13.040004  77.518099
# 1  unplanned  12.921876  77.645158
# 2  unplanned  12.955622  77.585708
# 3  unplanned  13.006147  77.579435
# 4  unplanned  12.953980  77.585233
#
#                                              address        event_cause  \
# 0  Mumbai Bengaluru Highway, Jalahalli Cross Junc...  vehicle_breakdown
# 1  19th Main Road, Heavie Halcyon, Agara, HSR Lay...  vehicle_breakdown
# 2  Lalbagh Main Road, Dr Sri Shantaveera Swami Ci...             others
# 3  Sankey Road, Bashyam Circle, Sadashiva Nagar, ...          tree_fall
# 4  Lalbagh Fort Road, Lalbagh Main Gate Junction,...  vehicle_breakdown
#
#    requires_road_closure              start_datetime    status authenticated  \
# 0                  False  2024-03-07 17:01:48.111+00    closed           yes
# 1                  False  2024-01-30 04:07:24.173+00  resolved           yes
# 2                  False  2023-11-11 06:18:03.343+00    closed           yes
# ...

# %%
df.columns
# Out:
# Index(['event_type', 'latitude', 'longitude', 'address', 'event_cause',
#        'requires_road_closure', 'start_datetime', 'status', 'authenticated',
#        'modified_datetime', 'veh_type', 'veh_no', 'corridor', 'priority',
#        'created_date', 'client_id', 'created_by_id', 'last_modified_by_id',
#        'police_station', 'kgid'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8166 entries, 0 to 8165
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_type             8166 non-null   str
#  1   latitude               8166 non-null   float64
#  2   longitude              8166 non-null   float64
#  3   address                8166 non-null   str
#  4   event_cause            8166 non-null   str
#  5   requires_road_closure  8166 non-null   bool
#  6   start_datetime         8166 non-null   str
#  7   status                 8166 non-null   str
#  8   authenticated          8166 non-null   str
#  9   modified_datetime      8166 non-null   str
#  10  veh_type               8166 non-null   str
#  11  veh_no                 8166 non-null   str
#  12  corridor               8166 non-null   str
#  13  priority               8166 non-null   str
#  14  created_date           8166 non-null   str
# ...

# %%
df.isnull().sum()
# Out:
# event_type               0
# latitude                 0
# longitude                0
# address                  0
# event_cause              0
# requires_road_closure    0
# start_datetime           0
# status                   0
# authenticated            0
# modified_datetime        0
# veh_type                 0
# veh_no                   0
# corridor                 0
# priority                 0
# created_date             0
# client_id                0
# created_by_id            0
# last_modified_by_id      0
# police_station           0
# kgid                     0
# dtype: int64

# %%
drop_cols=["address",
    "veh_no",
    "client_id",
    "created_by_id",
    "last_modified_by_id",
    "kgid",
    "created_date",
    "modified_datetime",
    "authenticated",
    "status"
          ]
df=df.drop(columns=drop_cols)

# %%
df.head()
# Out:
#   event_type   latitude  longitude        event_cause  requires_road_closure  \
# 0  unplanned  13.040004  77.518099  vehicle_breakdown                  False
# 1  unplanned  12.921876  77.645158  vehicle_breakdown                  False
# 2  unplanned  12.955622  77.585708             others                  False
# 3  unplanned  13.006147  77.579435          tree_fall                   True
# 4  unplanned  12.953980  77.585233  vehicle_breakdown                  False
#
#                start_datetime       veh_type      corridor priority  \
# 0  2024-03-07 17:01:48.111+00            lcv   Tumkur Road     High
# 1  2024-01-30 04:07:24.173+00  heavy_vehicle    ORR East 1     High
# 2  2023-11-11 06:18:03.343+00         others  Non-corridor      Low
# 3  2024-03-07 17:56:55.061+00         others  Non-corridor      Low
# 4  2024-01-30 04:56:32.348+00    private_bus  Non-corridor      Low
#
#    police_station
# 0          Peenya
# 1      HSR Layout
# 2   Wilson Garden
# ...

# %%
df["start_datetime"] = pd.to_datetime(df["start_datetime"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df["start_datetime"] = pd.to_datetime(df["start_datetime"])
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\tools\datetimes.py:1040, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1038         result = arg.map(cache_array)
#    1039     else:
# -> 1040         values = convert_listlike(arg._values, format)
#    1041         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1042 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
df["start_datetime"] = pd.to_datetime(df["start_datetime"])
df["hour"] = df["start_datetime"].dt.hour
df["day_of_week"] = df["start_datetime"].dt.day_name()
df["month"] = df["start_datetime"].dt.month
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df["start_datetime"] = pd.to_datetime(df["start_datetime"])
#       2 df["hour"] = df["start_datetime"].dt.hour
#       3 df["day_of_week"] = df["start_datetime"].dt.day_name()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\tools\datetimes.py:1040, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1038         result = arg.map(cache_array)
#    1039     else:
# -> 1040         values = convert_listlike(arg._values, format)
#    1041         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1042 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
df["start_datetime"].head(10)
# Out:
# 0       2024-03-07 17:01:48.111+00
# 1       2024-01-30 04:07:24.173+00
# 2       2023-11-11 06:18:03.343+00
# 3       2024-03-07 17:56:55.061+00
# 4       2024-01-30 04:56:32.348+00
# 5    2023-11-28 03:07:27.292421+00
# 6       2024-01-30 07:26:26.739+00
# 7       2024-01-30 06:05:59.339+00
# 8           2024-02-12 02:05:46+00
# 9       2024-01-30 05:25:50.078+00
# Name: start_datetime, dtype: str

# %%
df["start_datetime"] = pd.to_datetime(
    df["start_datetime"],
    format="mixed",
    utc=True
)

# %%
df["start_datetime"].head()
# Out:
# 0   2024-03-07 17:01:48.111000+00:00
# 1   2024-01-30 04:07:24.173000+00:00
# 2   2023-11-11 06:18:03.343000+00:00
# 3   2024-03-07 17:56:55.061000+00:00
# 4   2024-01-30 04:56:32.348000+00:00
# Name: start_datetime, dtype: datetime64[us, UTC]

# %%
df["hour"] = df["start_datetime"].dt.hour

df["day_of_week"] = df["start_datetime"].dt.day_name()

df["month"] = df["start_datetime"].dt.month

# %%
df[["start_datetime", "hour", "day_of_week", "month"]].head()
# Out:
#                     start_datetime  hour day_of_week  month
# 0 2024-03-07 17:01:48.111000+00:00    17    Thursday      3
# 1 2024-01-30 04:07:24.173000+00:00     4     Tuesday      1
# 2 2023-11-11 06:18:03.343000+00:00     6    Saturday     11
# 3 2024-03-07 17:56:55.061000+00:00    17    Thursday      3
# 4 2024-01-30 04:56:32.348000+00:00     4     Tuesday      1

# %%
df.shape
# Out:
# (8166, 13)

# %%
df["priority"].value_counts()
# Out:
# priority
# High    5027
# Low     3139
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['event_type', 'latitude', 'longitude', 'event_cause',
#        'requires_road_closure', 'start_datetime', 'veh_type', 'corridor',
#        'priority', 'police_station', 'hour', 'day_of_week', 'month'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8166 entries, 0 to 8165
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_type             8166 non-null   str
#  1   latitude               8166 non-null   float64
#  2   longitude              8166 non-null   float64
#  3   event_cause            8166 non-null   str
#  4   requires_road_closure  8166 non-null   bool
#  5   start_datetime         8166 non-null   datetime64[us, UTC]
#  6   veh_type               8166 non-null   str
#  7   corridor               8166 non-null   str
#  8   priority               8166 non-null   str
#  9   police_station         8166 non-null   str
#  10  hour                   8166 non-null   int32
#  11  day_of_week            8166 non-null   str
#  12  month                  8166 non-null   int32
# dtypes: bool(1), datetime64[us, UTC](1), float64(2), int32(2), str(7)
# memory usage: 709.9 KB

# %%
df = df.drop(columns=["start_datetime"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8166 entries, 0 to 8165
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_type             8166 non-null   str
#  1   latitude               8166 non-null   float64
#  2   longitude              8166 non-null   float64
#  3   event_cause            8166 non-null   str
#  4   requires_road_closure  8166 non-null   bool
#  5   veh_type               8166 non-null   str
#  6   corridor               8166 non-null   str
#  7   priority               8166 non-null   str
#  8   police_station         8166 non-null   str
#  9   hour                   8166 non-null   int32
#  10  day_of_week            8166 non-null   str
#  11  month                  8166 non-null   int32
# dtypes: bool(1), float64(2), int32(2), str(7)
# memory usage: 646.1 KB

# %%
df["requires_road_closure"] = df["requires_road_closure"].astype(int)

# %%
df["requires_road_closure"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: requires_road_closure, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoders = {}

# %%
categorical_cols = [
    "event_type",
    "event_cause",
    "veh_type",
    "corridor",
    "police_station",
    "day_of_week"
]

for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    encoders[col] = le

# %%
df["priority"] = df["priority"].map({
    "Low": 0,
    "High": 1
})

# %%
df["priority"].value_counts()
# Out:
# priority
# 1    5027
# 0    3139
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8166 entries, 0 to 8165
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_type             8166 non-null   int64
#  1   latitude               8166 non-null   float64
#  2   longitude              8166 non-null   float64
#  3   event_cause            8166 non-null   int64
#  4   requires_road_closure  8166 non-null   int64
#  5   veh_type               8166 non-null   int64
#  6   corridor               8166 non-null   int64
#  7   priority               8166 non-null   int64
#  8   police_station         8166 non-null   int64
#  9   hour                   8166 non-null   int32
#  10  day_of_week            8166 non-null   int64
#  11  month                  8166 non-null   int32
# dtypes: float64(2), int32(2), int64(8)
# memory usage: 701.9 KB

# %%
df.head()
# Out:
#    event_type   latitude  longitude  event_cause  requires_road_closure  \
# 0           1  13.040004  77.518099           14                      0
# 1           1  12.921876  77.645158           14                      0
# 2           1  12.955622  77.585708            6                      0
# 3           1  13.006147  77.579435           13                      1
# 4           1  12.953980  77.585233           14                      0
#
#    veh_type  corridor  priority  police_station  hour  day_of_week  month
# 0         4        19         1              39    17            4      3
# 1         2        12         1              15     4            5      1
# 2         5        11         0              51     6            2     11
# 3         5        11         0              43    17            4      3
# 4         6        11         0              51     4            5      1

# %%
df.to_csv(
    "preprocessed_data.csv",
    index=False
)
